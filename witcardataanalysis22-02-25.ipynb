# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('car_dekho.csv')
print(df.to_string())
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  Owner
# 0                         ritz  2014           3.35          5.590       27000    Petrol      Dealer       Manual      0
# 1                          sx4  2013           4.75          9.540       43000    Diesel      Dealer       Manual      0
# 2                         ciaz  2017           7.25          9.850        6900    Petrol      Dealer       Manual      0
# 3                      wagon r  2011           2.85          4.150        5200    Petrol      Dealer       Manual      0
# 4                        swift  2014           4.60          6.870       42450    Diesel      Dealer       Manual      0
# 5                vitara brezza  2018           9.25          9.830        2071    Diesel      Dealer       Manual      0
# 6                         ciaz  2015           6.75          8.120       18796    Petrol      Dealer       Manual      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
fuel = df['Fuel_Type'].value_counts()
colors = ['green','orange','red']
fuel.plot(kind='bar',color=colors)
plt.title('Fuel Distribution')
plt.ylabel('Car Count')
plt.grid()

# plt.plot()

# %%
fuel = df['Fuel_Type'].value_counts()
fuel.plot(kind='pie')
plt.show()

# %%
df['Transmission'].value_counts()
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %%
T = df['Transmission'].value_counts()
T.plot(kind='bar')
plt.title('Transimission')
plt.ylabel('Car_Count')
plt.show()

# %%
T = df['Transmission'].value_counts()
T.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Year'].value_counts()
# Out:
# Year
# 2015    61
# 2016    50
# 2014    38
# 2017    35
# 2013    33
# 2012    23
# 2011    19
# 2010    15
# 2008     7
# 2009     6
# 2006     4
# 2005     4
# 2003     2
# 2007     2
# 2018     1
# 2004     1
# Name: count, dtype: int64

# %%
y=df['Year'].value_counts()
colors = ['green','blue','red','yellow','green','blue','red','yellow','green',
          'blue','red','yellow','green','blue','red','yellow']
y.plot(kind='bar',color=colors)
# Out:
# <Axes: xlabel='Year'>

# %%
y=df['Year'].value_counts()
y.plot(kind='pie')
plt.show()

# %%
df['Seller_Type'].value_counts()
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
st = df['Seller_Type'].value_counts()
st.plot(kind='bar')
plt.title("Analysing Which Types of Sell is hers")
plt.ylabel("Y-Sells-Count")
plt.show()

# %% [markdown]
# c = df['Car_Name'].value_count()

# %%
plt.figure(figsize = (9,30))
c = df['Car_Name'].value_counts()
y = df['Year'].value_counts().sort_index()
print(c)
print(y)
plt.scatter(df['Year'],df['Car_Name'])
plt.show()
# Out:
# Car_Name
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: count, Length: 98, dtype: int64
# Year
# 2003     2
# 2004     1
# 2005     4
# 2006     4
# 2007     2
# 2008     7
# 2009     6
# 2010    15
# 2011    19
# 2012    23
# 2013    33
# 2014    38
# 2015    61
# 2016    50
# 2017    35
# 2018     1
# Name: count, dtype: int64

# %%
car_counts = df.groupby(['Year', 'Car_Name']).size().reset_index(name='Sales')

# Find the car with the highest sales in each year
best_selling = car_counts.loc[car_counts.groupby('Year')['Sales'].idxmax()]

print(best_selling)
# Out:
#      Year          Car_Name  Sales
# 0    2003               800      1
# 2    2004           corolla      1
# 4    2005            innova      3
# 5    2006  Bajaj Pulsar 150      1
# 9    2007         Hero Hunk      1
# 12   2008  Bajaj Pulsar 150      2
# 18   2009              city      2
# 28   2010     corolla altis      2
# 43   2011               i10      3
# 63   2012             verna      5
# 78   2013     corolla altis      4
# 100  2014             amaze      4
# 131  2015              city      8
# 169  2016              city      7
# 200  2017            innova      3
# 205  2018     vitara brezza      1

# %%
b = car_counts.loc[car_counts.groupby('Year')['Sales'].idxmax()]
b.plot(kind='bar')
# Out:
# <Axes: >
